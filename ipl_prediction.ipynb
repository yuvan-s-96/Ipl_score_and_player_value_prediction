# %% [markdown]
# # IPL predictions on 'value' of players

# %% [markdown]
# **This notebook is maintained as a proof of concept for the Github repo: https://github.com/adityarc19/IPL-player-value-prediction whose web app is deployed at --> https://ipl-player-value-pred-app.herokuapp.com/**

# %% [markdown]
# Aim of this notebook is to analyse the ipl player rankings dataset of all past seasons (i.e. 2008 to 2020) and then implement a suitable machine learning algorithm which would predict the 'Value' of players based on other input parameters.
# A web-scraped copy of the data files are stored at https://github.com/adityarc19/IPL-analysis/tree/main/data.

# %% [markdown]
# Original dataset source : http://www.cricmetric.com/ipl/ranks/

# %%
#import standard data sci libs
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Reading in the .csv datasets:

# %%
df_2019 = pd.read_csv('https://raw.githubusercontent.com/adityarc19/IPL-analysis/main/data/2019.csv')
df_2019
# Out:
#      Rank             Player                   Team  RAA   Wins  EFscore  \
# 0       1          DA Warner    Sunrisers Hyderabad  410  1.414    0.224
# 1       2         AD Russell  Kolkata Knight Riders  307  1.060    0.242
# 2       3           MS Dhoni    Chennai Super Kings  305  1.053    0.176
# 3       4        Imran Tahir    Chennai Super Kings  295  1.018    0.200
# 4       5           KL Rahul        Kings XI Punjab  288  0.994    0.217
# ..    ...                ...                    ...  ...    ...      ...
# 156   157        DS Kulkarni       Rajasthan Royals -155 -0.534    0.044
# 157   158            B Kumar    Sunrisers Hyderabad -158 -0.544    0.095
# 158   159      Kuldeep Yadav  Kolkata Knight Riders -159 -0.549    0.023
# 159   160          K Gowtham       Rajasthan Royals -201 -0.695    0.016
# 160   161  M Prasidh Krishna  Kolkata Knight Riders -276 -0.952    0.040
#
#          Salary       Value
# 0    $1,953,130  $2,742,662
# 1    $1,328,130  $2,200,658
# 2    $2,343,750  $2,189,940
# 3      $156,250  $2,136,352
# 4    $1,718,750  $2,099,606
# ..          ...         ...
# 156    $117,190   $-239,892
# 157  $1,328,130   $-255,203
# 158    $906,250   $-262,858
# 159    $968,750   $-486,397
# 160     $15,620   $-879,886
#
# [161 rows x 8 columns]

# %%
df_2020 = pd.read_csv('https://raw.githubusercontent.com/adityarc19/IPL-analysis/main/data/2020.csv')
df_2020
# Out:
#      Rank        Player                         Team  RAA   Wins  EFscore  \
# 0       1     JJ Bumrah               Mumbai Indians  379  1.281    0.238
# 1       2      KL Rahul              Kings XI Punjab  330  1.113    0.194
# 2       3      K Rabada               Delhi Capitals  320  1.082    0.232
# 3       4  Ishan Kishan               Mumbai Indians  261  0.881    0.157
# 4       5      S Dhawan               Delhi Capitals  249  0.842    0.168
# ..    ...           ...                          ...  ...    ...      ...
# 145   146      AR Patel               Delhi Capitals -180 -0.607    0.081
# 146   147      NA Saini  Royal Challengers Bangalore -191 -0.646    0.061
# 147   148       S Gopal             Rajasthan Royals -215 -0.726    0.067
# 148   149     KH Pandya               Mumbai Indians -251 -0.848    0.066
# 149   150     SP Narine        Kolkata Knight Riders -292 -0.988    0.051
#
#          Salary       Value
# 0    $1,093,750  $2,448,655
# 1    $1,718,750  $2,204,319
# 2      $656,250  $2,159,233
# 3      $968,750  $1,866,902
# 4      $812,500  $1,810,181
# ..          ...         ...
# 145    $714,300   $-297,218
# 146    $468,750   $-353,939
# 147     $31,250   $-470,290
# 148  $1,375,000   $-647,724
# 149  $1,953,130   $-851,338
#
# [150 rows x 8 columns]

# %%
df_2018 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2018.csv')
df_2018
# Out:
#      Rank         Player                   Team  RAA   Wins  EFscore  \
# 0       1  KS Williamson    Sunrisers Hyderabad  351  1.221    0.214
# 1       2       KL Rahul        Kings XI Punjab  328  1.141    0.193
# 2       3      AT Rayudu    Chennai Super Kings  327  1.137    0.198
# 3       4        RR Pant       Delhi Daredevils  322  1.122    0.201
# 4       5       MS Dhoni    Chennai Super Kings  290  1.011    0.167
# ..    ...            ...                    ...  ...    ...      ...
# 144   145    Shivam Mavi  Kolkata Knight Riders -190 -0.662    0.038
# 145   146       AR Patel        Kings XI Punjab -191 -0.665    0.039
# 146   147     JD Unadkat       Rajasthan Royals -204 -0.712    0.079
# 147   148      BA Stokes       Rajasthan Royals -207 -0.720    0.078
# 148   149       R Ashwin        Kings XI Punjab -215 -0.747    0.072
#
#          Salary       Value
# 0      $468,750  $2,397,239
# 1    $1,718,750  $2,280,549
# 2      $343,750  $2,274,714
# 3    $2,343,750  $2,252,835
# 4    $2,343,750  $2,090,927
# ..          ...         ...
# 144    $468,750   $-349,363
# 145  $1,953,130   $-353,739
# 146  $1,796,880   $-422,295
# 147  $1,953,130   $-433,964
# 148  $1,187,500   $-473,347
#
# [149 rows x 8 columns]

# %%
df_2017 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2017.csv')
df_2017
# Out:
#      Rank      Player                         Team  RAA   Wins  EFscore  \
# 0       1   DA Warner          Sunrisers Hyderabad  351  1.274    0.211
# 1       2  JD Unadkat      Rising Pune Supergiants  316  1.146    0.207
# 2       3     B Kumar          Sunrisers Hyderabad  304  1.104    0.228
# 3       4     HM Amla              Kings XI Punjab  236  0.854    0.151
# 4       5      AJ Tye                Gujarat Lions  205  0.742    0.132
# ..    ...         ...                          ...  ...    ...      ...
# 155   156   MM Sharma              Kings XI Punjab -171 -0.619    0.093
# 156   157   S Aravind  Royal Challengers Bangalore -183 -0.665    0.049
# 157   158   SR Watson  Royal Challengers Bangalore -196 -0.712    0.050
# 158   159    I Sharma          Sunrisers Hyderabad -217 -0.786    0.013
# 159   160   SP Narine        Kolkata Knight Riders -223 -0.807    0.121
#
#          Salary       Value
# 0      $916,000  $1,783,802
# 1       $45,000  $1,648,517
# 2      $708,000  $1,604,126
# 3           NaN  $1,339,898
# 4       $75,000  $1,221,524
# ..          ...         ...
# 155    $975,000   $-216,936
# 156         NaN   $-265,554
# 157  $1,425,000   $-315,229
# 158    $570,000   $-393,441
# 159    $700,000   $-415,636
#
# [160 rows x 8 columns]

# %%
df_2016 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2016.csv')
df_2016
# Out:
#      Rank          Player                         Team  RAA   Wins  EFscore  \
# 0       1         V Kohli  Royal Challengers Bangalore  615  2.041    0.365
# 1       2       DA Warner          Sunrisers Hyderabad  414  1.375    0.237
# 2       3  AB de Villiers  Royal Challengers Bangalore  307  1.019    0.189
# 3       4       YS Chahal  Royal Challengers Bangalore  251  0.833    0.155
# 4       5       G Gambhir        Kolkata Knight Riders  241  0.799    0.147
# ..    ...             ...                          ...  ...    ...      ...
# 153   154        VR Aaron  Royal Challengers Bangalore -151 -0.502    0.021
# 154   155      GJ Maxwell              Kings XI Punjab -159 -0.528    0.033
# 155   156         P Kumar                Gujarat Lions -214 -0.712    0.076
# 156   157       HH Pandya               Mumbai Indians -218 -0.722    0.028
# 157   158    MC Henriques          Sunrisers Hyderabad -227 -0.753    0.114
#
#          Salary       Value
# 0    $2,500,000  $2,594,886
# 1      $916,000  $1,890,050
# 2    $1,583,333  $1,513,292
# 3       $16,000  $1,316,446
# 4    $1,666,667  $1,280,463
# ..          ...         ...
# 153    $333,000    $-96,399
# 154  $1,000,000   $-123,916
# 155    $525,000   $-318,645
# 156     $16,667   $-329,228
# 157    $166,000   $-362,036
#
# [158 rows x 8 columns]

# %%
df_2015 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2015.csv')
df_2015
# Out:
#      Rank          Player                         Team  RAA   Wins  EFscore  \
# 0       1  AB de Villiers  Royal Challengers Bangalore  300  1.080    0.188
# 1       2       AM Rahane             Rajasthan Royals  274  0.986    0.180
# 2       3        DJ Bravo          Chennai Super Kings  251  0.901    0.227
# 3       4       DA Warner          Sunrisers Hyderabad  243  0.874    0.172
# 4       5    MC Henriques          Sunrisers Hyderabad  242  0.871    0.201
# ..    ...             ...                          ...  ...    ...      ...
# 140   141       HH Pandya               Mumbai Indians -165 -0.595    0.031
# 141   142        DJ Hooda             Rajasthan Royals -184 -0.660    0.037
# 142   143      GJ Maxwell              Kings XI Punjab -187 -0.673    0.047
# 143   144   R Vinay Kumar               Mumbai Indians -203 -0.732    0.044
# 144   145     JP Faulkner             Rajasthan Royals -271 -0.975    0.075
#
#          Salary       Value
# 0    $1,583,333  $1,689,095
# 1    $1,333,333  $1,585,393
# 2      $666,667  $1,491,620
# 3      $916,000  $1,461,833
# 4      $166,000  $1,458,524
# ..          ...         ...
# 140     $16,667   $-158,784
# 141     $66,000   $-230,492
# 142  $1,000,000   $-244,834
# 143    $466,000   $-309,924
# 144    $850,000   $-578,004
#
# [145 rows x 8 columns]

# %%
df_2014 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2014.csv')
df_2014
# Out:
#      Rank          Player                         Team  RAA   Wins  EFscore  \
# 0       1      RV Uthappa        Kolkata Knight Riders  285  0.968    0.210
# 1       2        MS Dhoni          Chennai Super Kings  229  0.779    0.143
# 2       3       DA Warner          Sunrisers Hyderabad  218  0.742    0.167
# 3       4      SL Malinga               Mumbai Indians  209  0.711    0.152
# 4       5        VR Aaron  Royal Challengers Bangalore  208  0.707    0.175
# ..    ...             ...                          ...  ...    ...      ...
# 147   148       JJ Bumrah               Mumbai Indians -149 -0.507    0.046
# 148   149        DW Steyn          Sunrisers Hyderabad -150 -0.512    0.097
# 149   150   R Vinay Kumar        Kolkata Knight Riders -157 -0.535    0.037
# 150   151  Mohammed Shami             Delhi Daredevils -201 -0.684    0.055
# 151   152         PP Ojha               Mumbai Indians -277 -0.944    0.037
#
#          Salary       Value
# 0      $833,000  $1,696,711
# 1    $2,083,333  $1,466,583
# 2      $916,000  $1,421,532
# 3    $1,350,000  $1,383,786
# 4      $333,000  $1,378,916
# ..          ...         ...
# 147    $200,000    $-99,257
# 148  $1,200,000   $-105,345
# 149    $466,000   $-133,350
# 150    $708,000   $-314,773
# 151    $541,000   $-631,351
#
# [152 rows x 8 columns]

# %%
df_2013 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2013.csv')
df_2013
# Out:
#      Rank      Player                         Team  RAA   Wins  EFscore  \
# 0       1    CH Gayle  Royal Challengers Bangalore  447  1.729    0.210
# 1       2  MEK Hussey          Chennai Super Kings  414  1.602    0.224
# 2       3     V Kohli  Royal Challengers Bangalore  339  1.311    0.179
# 3       4    DJ Bravo          Chennai Super Kings  258  1.001    0.218
# 4       5    SK Raina          Chennai Super Kings  253  0.981    0.143
# ..    ...         ...                          ...  ...    ...      ...
# 194   195     A Nehra             Delhi Daredevils -133 -0.515    0.051
# 195   196     B Kumar                Pune Warriors -144 -0.557    0.081
# 196   197   PP Chawla              Kings XI Punjab -180 -0.697    0.076
# 197   198   IK Pathan             Delhi Daredevils -183 -0.707    0.095
# 198   199    M Morkel             Delhi Daredevils -222 -0.858    0.049
#
#          Salary       Value
# 0    $2,000,000  $2,554,267
# 1      $425,000  $2,419,187
# 2    $1,800,000  $2,109,674
# 3      $200,000  $1,779,953
# 4    $1,300,000  $1,758,680
# ..          ...         ...
# 194         NaN    $167,507
# 195     $60,000    $122,835
# 196    $900,000    $-26,071
# 197  $1,900,000    $-36,708
# 198    $475,000   $-197,314
#
# [199 rows x 8 columns]

# %%
df_2012 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2012.csv')
df_2012
# Out:
#      Rank           Player                         Team  RAA   Wins  EFscore  \
# 0       1         CH Gayle  Royal Challengers Bangalore  354  1.286    0.212
# 1       2         S Dhawan              Deccan Chargers  304  1.103    0.208
# 2       3        SP Narine        Kolkata Knight Riders  298  1.082    0.187
# 3       4        G Gambhir        Kolkata Knight Riders  221  0.804    0.148
# 4       5        AM Rahane             Rajasthan Royals  217  0.787    0.156
# ..    ...              ...                          ...  ...    ...      ...
# 183   184          MS Gony              Deccan Chargers -144 -0.523    0.023
# 184   185          P Kumar              Kings XI Punjab -160 -0.580    0.087
# 185   186        YK Pathan        Kolkata Knight Riders -165 -0.598    0.065
# 186   187        IK Pathan             Delhi Daredevils -231 -0.839    0.091
# 187   188  Harbhajan Singh               Mumbai Indians -339 -1.231    0.061
#
#          Salary       Value
# 0      $650,000  $1,644,515
# 1      $300,000  $1,500,824
# 2      $700,000  $1,484,335
# 3    $2,400,000  $1,266,050
# 4           NaN  $1,252,702
# ..          ...         ...
# 183    $290,000    $224,093
# 184    $800,000    $179,337
# 185  $2,100,000    $165,204
# 186  $1,900,000    $-24,029
# 187    $850,000   $-331,826
#
# [188 rows x 8 columns]

# %%
df_2011 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2011.csv')
df_2011
# Out:
#      Rank        Player                         Team  RAA   Wins  EFscore  \
# 0       1      CH Gayle  Royal Challengers Bangalore  351  1.303    0.239
# 1       2    SL Malinga               Mumbai Indians  325  1.207    0.207
# 2       3   S Badrinath          Chennai Super Kings  267  0.990    0.160
# 3       4      SE Marsh              Kings XI Punjab  246  0.912    0.149
# 4       5  SR Tendulkar               Mumbai Indians  217  0.807    0.166
# ..    ...           ...                          ...  ...    ...      ...
# 193   194       NV Ojha             Delhi Daredevils -176 -0.652    0.033
# 194   195      M Manhas                Pune Warriors -186 -0.691    0.023
# 195   196    KA Pollard               Mumbai Indians -196 -0.727    0.091
# 196   197         B Lee        Kolkata Knight Riders -216 -0.801    0.041
# 197   198      A Mithun  Royal Challengers Bangalore -228 -0.847    0.039
#
#        Salary       Value
# 0    $650,000  $1,674,414
# 1         NaN  $1,592,801
# 2    $800,000  $1,408,322
# 3    $400,000  $1,342,011
# 4         NaN  $1,252,747
# ..        ...         ...
# 193  $270,000     $12,400
# 194       NaN    $-20,756
# 195  $750,000    $-51,360
# 196  $400,000   $-114,270
# 197  $260,000   $-153,377
#
# [198 rows x 8 columns]

# %%
df_2010 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2010.csv')
df_2010
# Out:
#      Rank            Player                         Team  RAA   Wins  EFscore  \
# 0       1      SR Tendulkar               Mumbai Indians  268  0.948    0.205
# 1       2          SK Raina          Chennai Super Kings  239  0.845    0.223
# 2       3  DPMD Jayawardene              Kings XI Punjab  195  0.691    0.146
# 3       4      KP Pietersen  Royal Challengers Bangalore  160  0.566    0.126
# 4       5         JH Kallis  Royal Challengers Bangalore  157  0.556    0.268
# ..    ...               ...                          ...  ...    ...      ...
# 174   175           P Kumar  Royal Challengers Bangalore -137 -0.486    0.074
# 175   176      AC Gilchrist              Deccan Chargers -144 -0.511    0.050
# 176   177             B Lee              Kings XI Punjab -153 -0.542    0.006
# 177   178         R McLaren               Mumbai Indians -167 -0.591    0.054
# 178   179          DJ Bravo               Mumbai Indians -243 -0.861    0.035
#
#          Salary       Value
# 0           NaN  $1,047,446
# 1      $650,000    $990,667
# 2      $475,000    $905,775
# 3    $1,550,000    $836,869
# 4      $900,000    $831,356
# ..          ...         ...
# 174         NaN    $256,954
# 175    $700,000    $243,172
# 176    $900,000    $226,084
# 177         NaN    $199,072
# 178         NaN     $50,235
#
# [179 rows x 8 columns]

# %%
df_2009 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2009.csv')
df_2009
# Out:
#      Rank          Player                         Team  RAA   Wins  EFscore  \
# 0       1       ML Hayden          Chennai Super Kings  338  1.366    0.238
# 1       2  AB de Villiers             Delhi Daredevils  256  1.037    0.195
# 2       3       JP Duminy               Mumbai Indians  191  0.775    0.177
# 3       4        BJ Hodge        Kolkata Knight Riders  189  0.766    0.196
# 4       5       RG Sharma              Deccan Chargers  156  0.630    0.174
# ..    ...             ...                          ...  ...    ...      ...
# 160   161         P Kumar  Royal Challengers Bangalore -103 -0.418    0.107
# 161   162   Harmeet Singh              Deccan Chargers -116 -0.470    0.019
# 162   163      SC Ganguly        Kolkata Knight Riders -119 -0.480    0.067
# 163   164       JH Kallis  Royal Challengers Bangalore -134 -0.544    0.146
# 164   165        AB Dinda        Kolkata Knight Riders -138 -0.557    0.028
#
#        Salary       Value
# 0    $375,000  $1,331,596
# 1    $300,000  $1,145,098
# 2    $950,000    $996,579
# 3         NaN    $991,477
# 4    $750,000    $914,384
# ..        ...         ...
# 160       NaN    $320,310
# 161       NaN    $290,833
# 162       NaN    $285,164
# 163  $900,000    $248,885
# 164       NaN    $241,516
#
# [165 rows x 8 columns]

# %%
df_2008 = pd.read_csv(r'C:\Users\yuvan\Downloads\IPL-player-value-prediction-main (1)\IPL-player-value-prediction-main\data\2008.csv')
df_2008
# Out:
#      Rank         Player                         Team  RAA   Wins  EFscore  \
# 0       1       SE Marsh              Kings XI Punjab  377  1.355    0.231
# 1       2      SR Watson             Rajasthan Royals  347  1.250    0.297
# 2       3  Sohail Tanvir             Rajasthan Royals  294  1.059    0.194
# 3       4      G Gambhir             Delhi Daredevils  216  0.776    0.160
# 4       5       GC Smith             Rajasthan Royals  202  0.725    0.139
# ..    ...            ...                          ...  ...    ...      ...
# 155   156      VRV Singh              Kings XI Punjab -142 -0.511    0.078
# 156   157       JR Hopes              Kings XI Punjab -158 -0.570    0.096
# 157   158      SB Styris              Deccan Chargers -161 -0.578    0.060
# 158   159      SB Bangar              Deccan Chargers -165 -0.594    0.037
# 159   160      JH Kallis  Royal Challengers Bangalore -236 -0.849    0.080
#
#        Salary       Value
# 0         NaN  $1,270,355
# 1    $125,000  $1,209,660
# 2         NaN  $1,099,252
# 3    $725,000    $935,664
# 4    $250,000    $906,183
# ..        ...         ...
# 155       NaN    $191,712
# 156       NaN    $157,607
# 157  $175,000    $152,983
# 158       NaN    $143,734
# 159  $900,000     $-3,669
#
# [160 rows x 8 columns]

# %% [markdown]
# Combining both years' datasets :

# %%
df = pd.concat([df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017,
               df_2018, df_2019, df_2020], axis=0)
df
# Out:
#      Rank         Player                         Team  RAA   Wins  EFscore  \
# 0       1       SE Marsh              Kings XI Punjab  377  1.355    0.231
# 1       2      SR Watson             Rajasthan Royals  347  1.250    0.297
# 2       3  Sohail Tanvir             Rajasthan Royals  294  1.059    0.194
# 3       4      G Gambhir             Delhi Daredevils  216  0.776    0.160
# 4       5       GC Smith             Rajasthan Royals  202  0.725    0.139
# ..    ...            ...                          ...  ...    ...      ...
# 145   146       AR Patel               Delhi Capitals -180 -0.607    0.081
# 146   147       NA Saini  Royal Challengers Bangalore -191 -0.646    0.061
# 147   148        S Gopal             Rajasthan Royals -215 -0.726    0.067
# 148   149      KH Pandya               Mumbai Indians -251 -0.848    0.066
# 149   150      SP Narine        Kolkata Knight Riders -292 -0.988    0.051
#
#          Salary       Value
# 0           NaN  $1,270,355
# 1      $125,000  $1,209,660
# 2           NaN  $1,099,252
# 3      $725,000    $935,664
# 4      $250,000    $906,183
# ..          ...         ...
# 145    $714,300   $-297,218
# 146    $468,750   $-353,939
# 147     $31,250   $-470,290
# 148  $1,375,000   $-647,724
# 149  $1,953,130   $-851,338
#
# [2164 rows x 8 columns]

# %%
df.drop(['Rank'],axis=1,inplace=True)

# %%
df.to_csv('df',index=False)

# %%
df=pd.read_csv('df')
df
# Out:
#              Player                         Team  RAA   Wins  EFscore  \
# 0          SE Marsh              Kings XI Punjab  377  1.355    0.231
# 1         SR Watson             Rajasthan Royals  347  1.250    0.297
# 2     Sohail Tanvir             Rajasthan Royals  294  1.059    0.194
# 3         G Gambhir             Delhi Daredevils  216  0.776    0.160
# 4          GC Smith             Rajasthan Royals  202  0.725    0.139
# ...             ...                          ...  ...    ...      ...
# 2159       AR Patel               Delhi Capitals -180 -0.607    0.081
# 2160       NA Saini  Royal Challengers Bangalore -191 -0.646    0.061
# 2161        S Gopal             Rajasthan Royals -215 -0.726    0.067
# 2162      KH Pandya               Mumbai Indians -251 -0.848    0.066
# 2163      SP Narine        Kolkata Knight Riders -292 -0.988    0.051
#
#           Salary       Value
# 0            NaN  $1,270,355
# 1       $125,000  $1,209,660
# 2            NaN  $1,099,252
# 3       $725,000    $935,664
# 4       $250,000    $906,183
# ...          ...         ...
# 2159    $714,300   $-297,218
# 2160    $468,750   $-353,939
# 2161     $31,250   $-470,290
# 2162  $1,375,000   $-647,724
# 2163  $1,953,130   $-851,338
#
# [2164 rows x 7 columns]

# %%
#Removing the dollar sign and commas from salary and value columns
df['Salary'] = df['Salary'].str.replace(',', '').str.replace('$', '').astype(float)
df['Value'] = df['Value'].str.replace(',', '').str.replace('$', '').astype(float)
df
# Out:
# C:\Users\yuvan\AppData\Local\Temp\ipykernel_2132\2663668534.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Salary'] = df['Salary'].str.replace(',', '').str.replace('$', '').astype(float)
# C:\Users\yuvan\AppData\Local\Temp\ipykernel_2132\2663668534.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Value'] = df['Value'].str.replace(',', '').str.replace('$', '').astype(float)
#              Player                         Team  RAA   Wins  EFscore  \
# 0          SE Marsh              Kings XI Punjab  377  1.355    0.231
# 1         SR Watson             Rajasthan Royals  347  1.250    0.297
# 2     Sohail Tanvir             Rajasthan Royals  294  1.059    0.194
# 3         G Gambhir             Delhi Daredevils  216  0.776    0.160
# 4          GC Smith             Rajasthan Royals  202  0.725    0.139
# ...             ...                          ...  ...    ...      ...
# 2159       AR Patel               Delhi Capitals -180 -0.607    0.081
# 2160       NA Saini  Royal Challengers Bangalore -191 -0.646    0.061
# 2161        S Gopal             Rajasthan Royals -215 -0.726    0.067
# 2162      KH Pandya               Mumbai Indians -251 -0.848    0.066
# 2163      SP Narine        Kolkata Knight Riders -292 -0.988    0.051
#
#          Salary      Value
# 0           NaN  1270355.0
# 1      125000.0  1209660.0
# 2           NaN  1099252.0
# 3      725000.0   935664.0
# 4      250000.0   906183.0
# ...         ...        ...
# 2159   714300.0  -297218.0
# 2160   468750.0  -353939.0
# 2161    31250.0  -470290.0
# 2162  1375000.0  -647724.0
# 2163  1953130.0  -851338.0
#
# [2164 rows x 7 columns]

# %% [markdown]
# ### Dataset analysis

# %%
sns.heatmap(df.corr()) #Checking inter-correlations among parameters
# Out:
# C:\Users\yuvan\AppData\Local\Temp\ipykernel_2132\3727246609.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr()) #Checking inter-correlations among parameters
# <Axes: >

# %%
#dataframe for numerical cols
num_data = df[['RAA','Wins','EFscore','Salary','Value']]
num_data
# Out:
#       RAA   Wins  EFscore     Salary      Value
# 0     377  1.355    0.231        NaN  1270355.0
# 1     347  1.250    0.297   125000.0  1209660.0
# 2     294  1.059    0.194        NaN  1099252.0
# 3     216  0.776    0.160   725000.0   935664.0
# 4     202  0.725    0.139   250000.0   906183.0
# ...   ...    ...      ...        ...        ...
# 2159 -180 -0.607    0.081   714300.0  -297218.0
# 2160 -191 -0.646    0.061   468750.0  -353939.0
# 2161 -215 -0.726    0.067    31250.0  -470290.0
# 2162 -251 -0.848    0.066  1375000.0  -647724.0
# 2163 -292 -0.988    0.051  1953130.0  -851338.0
#
# [2164 rows x 5 columns]

# %%
num_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2164 entries, 0 to 2163
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RAA      2164 non-null   int64
#  1   Wins     2164 non-null   float64
#  2   EFscore  2164 non-null   float64
#  3   Salary   1526 non-null   float64
#  4   Value    2164 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 84.7 KB

# %%
num_data.describe()
# Out:
#                RAA         Wins      EFscore        Salary         Value
# count  2164.000000  2164.000000  2164.000000  1.526000e+03  2.164000e+03
# mean      0.018946     0.000055     0.057640  5.483967e+05  5.545682e+05
# std      93.514742     0.334372     0.051832  5.337490e+05  3.740137e+05
# min    -339.000000    -1.231000     0.000000  1.500000e+04 -8.798860e+05
# 25%     -53.000000    -0.189250     0.015000  1.492500e+05  3.696000e+05
# 50%     -15.000000    -0.052000     0.044000  4.000000e+05  5.086590e+05
# 75%      37.000000     0.133250     0.089000  7.500000e+05  6.795565e+05
# max     615.000000     2.041000     0.365000  3.000000e+06  2.742662e+06

# %%
# null counts
num_data.isnull().sum()
# Out:
# RAA          0
# Wins         0
# EFscore      0
# Salary     638
# Value        0
# dtype: int64

# %%
sns.pairplot(num_data)

# %% [markdown]
# From looking at the diagrams above, the data looks like it could be fit using algorithms like linear regression, lasso regression, etc.

# %% [markdown]
# Before finalising a regression model for prediction, lets first analyse all the possible regression models that could potentially be used for the data. To do the same, I have used **PyCaret**.

# %% [markdown]
# ### ML Models Analysis using PyCaret

# %%
# !pip install pycaret
# Out:
# ^C
# Collecting pycaret
#   Using cached pycaret-3.0.0-py3-none-any.whl (481 kB)
# Collecting deprecation>=2.1.0
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy<1.25,>=1.21 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.23.5)
# Requirement already satisfied: schemdraw>=0.14 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.16)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.2.0)
# Collecting plotly-resampler>=0.8.3.1
#   Using cached plotly_resampler-0.8.3.2-cp310-cp310-win_amd64.whl
# Collecting sktime>=0.16.1
#   Using cached sktime-0.16.1-py3-none-any.whl (16.0 MB)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.1.2)
# Collecting nbformat>=4.2.0
#   Using cached nbformat-5.8.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from pycaret) (5.9.4)
# Requirement already satisfied: jinja2>=1.2 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.1.2)
# Collecting pyod>=1.0.8
#   Using cached pyod-1.0.9.tar.gz (149 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting plotly>=5.0.0
#   Using cached plotly-5.13.1-py2.py3-none-any.whl (15.2 MB)
# Collecting imbalanced-learn>=0.8.1
#   Using cached imbalanced_learn-0.10.1-py3-none-any.whl (226 kB)
# Collecting ipywidgets>=7.6.5
#   Using cached ipywidgets-8.0.5-py3-none-any.whl (138 kB)
# Collecting pmdarima!=1.8.1,<3.0.0,>=1.8.0
#   Using cached pmdarima-2.0.3-cp310-cp310-win_amd64.whl (569 kB)
# Collecting statsmodels>=0.12.1
#   Using cached statsmodels-0.13.5-cp310-cp310-win_amd64.whl (9.1 MB)
# Collecting cloudpickle
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from pycaret) (8.11.0)
# Collecting tbats>=1.1.0
#   Using cached tbats-1.1.2-py3-none-any.whl (43 kB)
# Requirement already satisfied: xxhash in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.2.0)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.7.1)
# Collecting numba>=0.55.0
#   Using cached numba-0.56.4-cp310-cp310-win_amd64.whl (2.5 MB)
# Collecting yellowbrick>=1.4
#   Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# Collecting category-encoders>=2.4.0
#   Using cached category_encoders-2.6.0-py2.py3-none-any.whl (81 kB)
# Collecting scikit-plot>=0.3.7
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (6.1.0)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: scipy<2.0.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.2.1)
# Collecting lightgbm>=3.0.0
#   Using cached lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: requests>=2.27.1 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.28.2)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.2.2)
# Collecting patsy>=0.5.1
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: packaging in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from deprecation>=2.1.0->pycaret) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.15.0)
# Requirement already satisfied: backcall in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (3.0.38)
# Requirement already satisfied: traitlets>=5 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (5.9.0)
# Requirement already satisfied: stack-data in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.6.2)
# Requirement already satisfied: colorama in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (2.14.0)
# Requirement already satisfied: matplotlib-inline in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: decorator in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.18.2)
# Collecting jupyterlab-widgets~=3.0
#   Using cached jupyterlab_widgets-3.0.6-py3-none-any.whl (198 kB)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.6)
# Requirement already satisfied: wheel in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.40.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.39.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: fastjsonschema in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.3)
# Requirement already satisfied: jupyter-core in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from nbformat>=4.2.0->pycaret) (5.3.0)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Using cached llvmlite-0.39.1-cp310-cp310-win_amd64.whl (23.2 MB)
# Requirement already satisfied: setuptools in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.55.0->pycaret) (63.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pandas<1.6.0,>=1.3.0->pycaret) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from plotly>=5.0.0->pycaret) (8.2.2)
# Requirement already satisfied: trace-updater>=0.0.8 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.8.8)
# Collecting dash<3.0.0,>=2.2.0
#   Using cached dash-2.9.1-py3-none-any.whl (10.2 MB)
# Collecting jupyter-dash>=0.4.2
#   Using cached jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: urllib3 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.15)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Using cached Cython-0.29.33-py2.py3-none-any.whl (987 kB)
# Requirement already satisfied: six in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (2022.12.7)
# Collecting deprecated>=1.2.13
#   Using cached Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret) (1.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.2.0)
# Requirement already satisfied: retrying in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Collecting ansi2html
#   Using cached ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: ipykernel in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (6.22.0)
# Requirement already satisfied: nest-asyncio in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: wcwidth in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (3.1.1)
# Requirement already satisfied: pywin32>=300 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=5.5.0->pycaret) (1.2.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\yuvan\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (6.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: pyzmq>=20 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (25.0.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (8.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\yuvan\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.6.6)
# Building wheels for collected packages: pyod
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.0.9-py3-none-any.whl size=184165 sha256=974b783174e37eff5b19272f8169d89a55d9ddc045c36061a2181193b62c8150
#   Stored in directory: c:\users\yuvan\appdata\local\pip\cache\wheels\83\55\6b\552e083cf5509c0afe808b76cf434f1be284d01a112623bd37
# Successfully built pyod
# Installing collected packages: plotly, patsy, llvmlite, jupyterlab-widgets, deprecation, deprecated, Cython, cloudpickle, ansi2html, numba, nbformat, yellowbrick, statsmodels, sktime, scikit-plot, pyod, lightgbm, imbalanced-learn, dash, pmdarima, ipywidgets, category-encoders, tbats, jupyter-dash, plotly-resampler, pycaret
# Successfully installed Cython-0.29.33 ansi2html-1.8.0 category-encoders-2.6.0 cloudpickle-2.2.1 dash-2.9.1 deprecated-1.2.13 deprecation-2.1.0 imbalanced-learn-0.10.1 ipywidgets-8.0.5 jupyter-dash-0.4.2 jupyterlab-widgets-3.0.6 lightgbm-3.3.5 llvmlite-0.39.1 nbformat-5.8.0 numba-0.56.4 patsy-0.5.3 plotly-5.13.1 plotly-resampler-0.8.3.2 pmdarima-2.0.3 pycaret-3.0.0 pyod-1.0.9 scikit-plot-0.3.7 sktime-0.16.1 statsmodels-0.13.5 tbats-1.1.2 yellowbrick-1.5

# %%
from pycaret.regression import *

# %%
xgb = create_model('xgboost')   #Model creation
# Out:
#               MAE           MSE         RMSE      R2   RMSLE    MAPE
# 0     101382.8594  1.914898e+10  138379.8459  0.8668  0.6113  0.2330
# 1      89827.8477  1.296889e+10  113881.0190  0.8956  0.4730 -0.0480
# 2      99037.6589  1.513489e+10  123023.9271  0.8904  0.6341  0.1648
# 3      91750.8528  1.719314e+10  131122.6234  0.8589  0.4888  0.1080
# 4     100457.7606  2.069577e+10  143860.2537  0.8816  0.4764  0.0738
# 5      82885.2924  1.553565e+10  124642.0893  0.9130  0.4048  0.0494
# 6      86097.9196  1.283922e+10  113310.2773  0.8932  0.5355  0.5919
# 7      83777.9165  1.224520e+10  110658.0394  0.9036  0.3871  0.1380
# 8      88312.5725  1.178407e+10  108554.4449  0.9290  0.5261  0.0800
# 9      86967.8626  1.262391e+10  112356.1900  0.8989  0.7586  0.4195
# Mean   91049.8543  1.501697e+10  121978.8710  0.8931  0.5296  0.1810
# SD      6552.0042  2.951937e+09   11752.7534  0.0196  0.1066  0.1809

# %%
xgb
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=2380,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=0)

# %%
tuned_xgb = tune_model('xgboost')    #Tuning hyperparameters
# Out:
#               MAE           MSE         RMSE      R2   RMSLE    MAPE
# 0     101515.4579  2.079541e+10  144206.1471  0.8554  0.4976  0.2921
# 1      91132.2833  1.473004e+10  121367.3582  0.8814  0.5533  0.1710
# 2      98244.7063  1.582527e+10  125798.5148  0.8854  0.4038  0.1864
# 3      99185.0225  2.121667e+10  145659.4402  0.8259  0.4238  0.1327
# 4     105395.2183  2.345102e+10  153137.2591  0.8659  0.4218  0.0826
# 5      95468.8771  2.125619e+10  145795.0351  0.8810  0.4875  0.0243
# 6      91988.5244  1.652919e+10  128565.8867  0.8626  0.5695  0.6925
# 7      89067.8235  1.536449e+10  123953.5724  0.8790  0.4067  0.1581
# 8      97091.0368  1.694374e+10  130168.1183  0.8978  0.4394  0.1059
# 9      92202.0601  1.543537e+10  124239.1774  0.8764  0.5719  0.4087
# Mean   96129.1010  1.815474e+10  134289.0509  0.8711  0.4775  0.2255
# SD      4872.8357  3.007701e+09   11008.6116  0.0190  0.0644  0.1868

# %%
tuned_xgb
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=60, min_child_weight=4, missing=None, n_estimators=100,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=2380,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=0.9, verbosity=0)

# %%
evaluate_model(tuned_xgb)

# %%
 import pickle
 pickle.dump(tuned_xgb, open('model.pkl','wb'))
